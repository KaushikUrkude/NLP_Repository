# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
Paragraph = """The octopus is a fascinating marine creature known for its intelligence, unique appearance, and remarkable abilities. Belonging to the class Cephalopoda, which also includes squids and cuttlefish, octopuses are highly adaptable and can be found in various ocean environments, from shallow coastal waters to deep-sea regions.
Key characteristics of octopuses include their soft, bulbous bodies, large heads, and distinctive arms, usually eight in number. Each arm is lined with suckers that are highly sensitive to touch and taste. Octopuses are known for their exceptional problem-solving abilities, which are attributed to their well-developed nervous system and complex brain.
One of the most intriguing features of octopuses is their ability to change color and texture rapidly, allowing them to blend into their surroundings for camouflage or communicate with other octopuses. This camouflaging ability is achieved through specialized pigment cells called chromatophores in their skin.
Octopuses are also known for their intelligence, exhibiting advanced problem-solving skills, memory, and the ability to learn through observation. They have been observed using tools, escaping from predators, and even opening jars to access food. Some species of octopuses are also known for their unique behaviors, such as mimicry, where they imitate other marine animals to avoid predators.
Reproduction in octopuses is a fascinating process. Males typically use a specialized arm called a hectocotylus to transfer sperm to the female's mantle during mating. After laying a large number of eggs, the female guards and cares for them until they hatch. Interestingly, octopuses are semelparous, meaning they reproduce only once in their lifetime, and females often die shortly after their eggs hatch.
Despite their intriguing characteristics, octopuses have relatively short lifespans, ranging from a few months to a couple of years, depending on the species. Their adaptability, intelligence, and unique features make octopuses subjects of great interest in marine biology and have inspired curiosity and awe among scientists and enthusiasts alike.
"""

# %%
sentences = nltk.word_tokenize(Paragraph)

# %%
sentences
# Out:
# ['The',
#  'octopus',
#  'is',
#  'a',
#  'fascinating',
#  'marine',
#  'creature',
#  'known',
#  'for',
#  'its',
#  'intelligence',
#  ',',
#  'unique',
#  'appearance',
#  ',',
#  'and',
#  'remarkable',
#  'abilities',
#  '.',
#  'Belonging',
#  'to',
#  'the',
#  'class',
#  'Cephalopoda',
#  ',',
#  'which',
#  'also',
#  'includes',
#  'squids',
#  'and',
#  'cuttlefish',
#  ',',
#  'octopuses',
#  'are',
#  'highly',
#  'adaptable',
#  'and',
#  'can',
#  'be',
#  'found',
#  'in',
#  'various',
#  'ocean',
#  'environments',
#  ',',
#  'from',
#  'shallow',
#  'coastal',
#  'waters',
#  'to',
#  'deep-sea',
#  'regions',
#  '.',
#  'Key',
#  'characteristics',
#  'of',
#  'octopuses',
#  'include',
#  'their',
#  'soft',
#  ',',
#  'bulbous',
#  'bodies',
#  ',',
#  'large',
#  'heads',
#  ',',
#  'and',
#  'distinctive',
#  'arms',
#  ',',
#  'usually',
#  'eight',
#  'in',
#  'number',
#  '.',
#  'Each',
#  'arm',
#  'is',
#  'lined',
#  'with',
#  'suckers',
#  'that',
#  'are',
#  'highly',
#  'sensitive',
#  'to',
#  'touch',
#  'and',
#  'taste',
#  '.',
#  'Octopuses',
#  'are',
#  'known',
#  'for',
#  'their',
#  'exceptional',
#  'problem-solving',
#  'abilities',
#  ',',
#  'which',
#  'are',
#  'attributed',
#  'to',
#  'their',
#  'well-developed',
#  'nervous',
#  'system',
#  'and',
#  'complex',
#  'brain',
#  '.',
#  'One',
#  'of',
#  'the',
#  'most',
#  'intriguing',
#  'features',
#  'of',
#  'octopuses',
#  'is',
#  'their',
#  'ability',
#  'to',
#  'change',
#  'color',
#  'and',
#  'texture',
#  'rapidly',
#  ',',
#  'allowing',
#  'them',
#  'to',
#  'blend',
#  'into',
#  'their',
#  'surroundings',
#  'for',
#  'camouflage',
#  'or',
#  'communicate',
#  'with',
#  'other',
#  'octopuses',
#  '.',
#  'This',
#  'camouflaging',
#  'ability',
#  'is',
#  'achieved',
#  'through',
#  'specialized',
#  'pigment',
#  'cells',
#  'called',
#  'chromatophores',
#  'in',
#  'their',
#  'skin',
#  '.',
#  'Octopuses',
#  'are',
#  'also',
#  'known',
#  'for',
#  'their',
#  'intelligence',
#  ',',
#  'exhibiting',
#  'advanced',
#  'problem-solving',
#  'skills',
#  ',',
#  'memory',
#  ',',
#  'and',
#  'the',
#  'ability',
#  'to',
#  'learn',
#  'through',
#  'observation',
#  '.',
#  'They',
#  'have',
#  'been',
#  'observed',
#  'using',
#  'tools',
#  ',',
#  'escaping',
#  'from',
#  'predators',
#  ',',
#  'and',
#  'even',
#  'opening',
#  'jars',
#  'to',
#  'access',
#  'food',
#  '.',
#  'Some',
#  'species',
#  'of',
#  'octopuses',
#  'are',
#  'also',
#  'known',
#  'for',
#  'their',
#  'unique',
#  'behaviors',
#  ',',
#  'such',
#  'as',
#  'mimicry',
#  ',',
#  'where',
#  'they',
#  'imitate',
#  'other',
#  'marine',
#  'animals',
#  'to',
#  'avoid',
#  'predators',
#  '.',
#  'Reproduction',
#  'in',
#  'octopuses',
#  'is',
#  'a',
#  'fascinating',
#  'process',
#  '.',
#  'Males',
#  'typically',
#  'use',
#  'a',
#  'specialized',
#  'arm',
#  'called',
#  'a',
#  'hectocotylus',
#  'to',
#  'transfer',
#  'sperm',
#  'to',
#  'the',
#  'female',
#  "'s",
#  'mantle',
#  'during',
#  'mating',
#  '.',
#  'After',
#  'laying',
#  'a',
#  'large',
#  'number',
#  'of',
#  'eggs',
#  ',',
#  'the',
#  'female',
#  'guards',
#  'and',
#  'cares',
#  'for',
#  'them',
#  'until',
#  'they',
#  'hatch',
#  '.',
#  'Interestingly',
#  ',',
#  'octopuses',
#  'are',
#  'semelparous',
#  ',',
#  'meaning',
#  'they',
#  'reproduce',
#  'only',
#  'once',
#  'in',
#  'their',
#  'lifetime',
#  ',',
#  'and',
#  'females',
#  'often',
#  'die',
#  'shortly',
#  'after',
#  'their',
#  'eggs',
#  'hatch',
#  '.',
#  'Despite',
#  'their',
#  'intriguing',
#  'characteristics',
#  ',',
#  'octopuses',
#  'have',
#  'relatively',
#  'short',
#  'lifespans',
#  ',',
#  'ranging',
#  'from',
#  'a',
#  'few',
#  'months',
#  'to',
#  'a',
#  'couple',
#  'of',
#  'years',
#  ',',
#  'depending',
#  'on',
#  'the',
#  'species',
#  '.',
#  'Their',
#  'adaptability',
#  ',',
#  'intelligence',
#  ',',
#  'and',
#  'unique',
#  'features',
#  'make',
#  'octopuses',
#  'subjects',
#  'of',
#  'great',
#  'interest',
#  'in',
#  'marine',
#  'biology',
#  'and',
#  'have',
#  'inspired',
#  'curiosity',
#  'and',
#  'awe',
#  'among',
#  'scientists',
#  'and',
#  'enthusiasts',
#  'alike',
#  '.']

# %%
from nltk.corpus import stopwords
stopwords.words('english')

# %%
# CC coordinating conjunction
# CD cardinal digit
# DT determiner
# EX existential there (like: “there is” … think of it like “there exists”)
# FW foreign word
# IN preposition/subordinating conjunction
# JJ adjective ‘big’
# JJR adjective, comparative ‘bigger’
# JJS adjective, superlative ‘biggest’
# LS list marker 1)
# MD modal could, will
# NN noun, singular ‘desk’
# NNS noun plural ‘desks’
# NNP proper noun, singular ‘Harrison’
# NNPS proper noun, plural ‘Americans’
# PDT predeterminer ‘all the kids’
# POS possessive ending parent’s
# PRP personal pronoun I, he, she
# PRP$ possessive pronoun my, his, hers
# RB adverb very, silently,
# RBR adverb, comparative better
# RBS adverb, superlative best
# RP particle give up
# TO, to go ‘to’ the store.
# UH interjection, errrrrrrrm
# VB verb, base form take
# VBD verb, past tense took
# VBG verb, gerund/present participle taking
# VBN verb, past participle taken
# VBP verb, sing. present, non-3d take
# VBZ verb, 3rd person sing. present takes
# WDT wh-determiner which
# WP wh-pronoun who, what
# WP$ possessive wh-pronoun whose
# WRB wh-abverb where, when

# %%
for i in range(len(sentences)):
  words = nltk.word_tokenize(sentences[i])
  words = [word for word in words if word not in set(stopwords.words('english')  )]
  postag = nltk.pos_tag(words)
  print(postag)
# Out:
# [('The', 'DT'), ('octopus', 'NN'), ('fascinating', 'VBG'), ('marine', 'JJ'), ('creature', 'NN'), ('known', 'VBN'), ('intelligence', 'NN'), (',', ','), ('unique', 'JJ'), ('appearance', 'NN'), (',', ','), ('remarkable', 'JJ'), ('abilities', 'NNS'), ('.', '.')]
# [('Belonging', 'VBG'), ('class', 'NN'), ('Cephalopoda', 'NNP'), (',', ','), ('also', 'RB'), ('includes', 'VBZ'), ('squids', 'NNS'), ('cuttlefish', 'NN'), (',', ','), ('octopuses', 'VBZ'), ('highly', 'RB'), ('adaptable', 'JJ'), ('found', 'VBN'), ('various', 'JJ'), ('ocean', 'JJ'), ('environments', 'NNS'), (',', ','), ('shallow', 'JJ'), ('coastal', 'JJ'), ('waters', 'NNS'), ('deep-sea', 'JJ'), ('regions', 'NNS'), ('.', '.')]
# [('Key', 'NNP'), ('characteristics', 'NNS'), ('octopuses', 'NNS'), ('include', 'VBP'), ('soft', 'JJ'), (',', ','), ('bulbous', 'JJ'), ('bodies', 'NNS'), (',', ','), ('large', 'JJ'), ('heads', 'NNS'), (',', ','), ('distinctive', 'JJ'), ('arms', 'NNS'), (',', ','), ('usually', 'RB'), ('eight', 'CD'), ('number', 'NN'), ('.', '.')]
# [('Each', 'DT'), ('arm', 'NN'), ('lined', 'VBD'), ('suckers', 'NNS'), ('highly', 'RB'), ('sensitive', 'JJ'), ('touch', 'NN'), ('taste', 'NN'), ('.', '.')]
# [('Octopuses', 'NNS'), ('known', 'VBN'), ('exceptional', 'JJ'), ('problem-solving', 'NN'), ('abilities', 'NNS'), (',', ','), ('attributed', 'VBD'), ('well-developed', 'JJ'), ('nervous', 'JJ'), ('system', 'NN'), ('complex', 'JJ'), ('brain', 'NN'), ('.', '.')]
# [('One', 'CD'), ('intriguing', 'NN'), ('features', 'VBZ'), ('octopuses', 'VBZ'), ('ability', 'NN'), ('change', 'NN'), ('color', 'NN'), ('texture', 'NN'), ('rapidly', 'RB'), (',', ','), ('allowing', 'VBG'), ('blend', 'JJ'), ('surroundings', 'NNS'), ('camouflage', 'NN'), ('communicate', 'NN'), ('octopuses', 'NNS'), ('.', '.')]
# [('This', 'DT'), ('camouflaging', 'VBG'), ('ability', 'NN'), ('achieved', 'VBN'), ('specialized', 'JJ'), ('pigment', 'NN'), ('cells', 'NNS'), ('called', 'VBN'), ('chromatophores', 'NNS'), ('skin', 'FW'), ('.', '.')]
# [('Octopuses', 'NNS'), ('also', 'RB'), ('known', 'VBN'), ('intelligence', 'NN'), (',', ','), ('exhibiting', 'VBG'), ('advanced', 'JJ'), ('problem-solving', 'JJ'), ('skills', 'NNS'), (',', ','), ('memory', 'NN'), (',', ','), ('ability', 'NN'), ('learn', 'JJ'), ('observation', 'NN'), ('.', '.')]
# [('They', 'PRP'), ('observed', 'VBD'), ('using', 'VBG'), ('tools', 'NNS'), (',', ','), ('escaping', 'VBG'), ('predators', 'NNS'), (',', ','), ('even', 'RB'), ('opening', 'VBG'), ('jars', 'NNS'), ('access', 'NN'), ('food', 'NN'), ('.', '.')]
# [('Some', 'DT'), ('species', 'NNS'), ('octopuses', 'NNS'), ('also', 'RB'), ('known', 'VBN'), ('unique', 'JJ'), ('behaviors', 'NNS'), (',', ','), ('mimicry', 'NN'), (',', ','), ('imitate', 'JJ'), ('marine', 'NN'), ('animals', 'NNS'), ('avoid', 'VBP'), ('predators', 'NNS'), ('.', '.')]
# [('Reproduction', 'NN'), ('octopuses', 'VBZ'), ('fascinating', 'VBG'), ('process', 'NN'), ('.', '.')]
# [('Males', 'NNS'), ('typically', 'RB'), ('use', 'VBP'), ('specialized', 'JJ'), ('arm', 'NN'), ('called', 'VBN'), ('hectocotylus', 'NN'), ('transfer', 'NN'), ('sperm', 'JJ'), ('female', 'NN'), ("'s", 'POS'), ('mantle', 'JJ'), ('mating', 'NN'), ('.', '.')]
# [('After', 'IN'), ('laying', 'VBG'), ('large', 'JJ'), ('number', 'NN'), ('eggs', 'NNS'), (',', ','), ('female', 'JJ'), ('guards', 'NNS'), ('cares', 'NNS'), ('hatch', 'VBP'), ('.', '.')]
# [('Interestingly', 'RB'), (',', ','), ('octopuses', 'VBZ'), ('semelparous', 'JJ'), (',', ','), ('meaning', 'VBG'), ('reproduce', 'NN'), ('lifetime', 'NN'), (',', ','), ('females', 'NNS'), ('often', 'RB'), ('die', 'VBP'), ('shortly', 'RB'), ('eggs', 'JJ'), ('hatch', 'NN'), ('.', '.')]
# [('Despite', 'IN'), ('intriguing', 'JJ'), ('characteristics', 'NNS'), (',', ','), ('octopuses', 'VBZ'), ('relatively', 'RB'), ('short', 'JJ'), ('lifespans', 'NNS'), (',', ','), ('ranging', 'VBG'), ('months', 'NNS'), ('couple', 'NN'), ('years', 'NNS'), (',', ','), ('depending', 'VBG'), ('species', 'NNS'), ('.', '.')]
# [('Their', 'PRP$'), ('adaptability', 'NN'), (',', ','), ('intelligence', 'NN'), (',', ','), ('unique', 'JJ'), ('features', 'NNS'), ('make', 'VBP'), ('octopuses', 'NNS'), ('subjects', 'VBZ'), ('great', 'JJ'), ('interest', 'NN'), ('marine', 'NN'), ('biology', 'NN'), ('inspired', 'VBN'), ('curiosity', 'NN'), ('awe', 'NN'), ('among', 'IN'), ('scientists', 'NNS'), ('enthusiasts', 'NNS'), ('alike', 'RB'), ('.', '.')]

# %%
print(nltk.pos_tag(sentences)) ##input is a list of string
# Out:
# [('The', 'DT'), ('octopus', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('fascinating', 'JJ'), ('marine', 'JJ'), ('creature', 'NN'), ('known', 'VBN'), ('for', 'IN'), ('its', 'PRP$'), ('intelligence', 'NN'), (',', ','), ('unique', 'JJ'), ('appearance', 'NN'), (',', ','), ('and', 'CC'), ('remarkable', 'JJ'), ('abilities', 'NNS'), ('.', '.'), ('Belonging', 'VBG'), ('to', 'TO'), ('the', 'DT'), ('class', 'NN'), ('Cephalopoda', 'NNP'), (',', ','), ('which', 'WDT'), ('also', 'RB'), ('includes', 'VBZ'), ('squids', 'NNS'), ('and', 'CC'), ('cuttlefish', 'JJ'), (',', ','), ('octopuses', 'NNS'), ('are', 'VBP'), ('highly', 'RB'), ('adaptable', 'JJ'), ('and', 'CC'), ('can', 'MD'), ('be', 'VB'), ('found', 'VBN'), ('in', 'IN'), ('various', 'JJ'), ('ocean', 'JJ'), ('environments', 'NNS'), (',', ','), ('from', 'IN'), ('shallow', 'JJ'), ('coastal', 'JJ'), ('waters', 'NNS'), ('to', 'TO'), ('deep-sea', 'JJ'), ('regions', 'NNS'), ('.', '.'), ('Key', 'NNP'), ('characteristics', 'NNS'), ('of', 'IN'), ('octopuses', 'NNS'), ('include', 'VBP'), ('their', 'PRP$'), ('soft', 'JJ'), (',', ','), ('bulbous', 'JJ'), ('bodies', 'NNS'), (',', ','), ('large', 'JJ'), ('heads', 'NNS'), (',', ','), ('and', 'CC'), ('distinctive', 'JJ'), ('arms', 'NNS'), (',', ','), ('usually', 'RB'), ('eight', 'CD'), ('in', 'IN'), ('number', 'NN'), ('.', '.'), ('Each', 'DT'), ('arm', 'NN'), ('is', 'VBZ'), ('lined', 'VBN'), ('with', 'IN'), ('suckers', 'NNS'), ('that', 'WDT'), ('are', 'VBP'), ('highly', 'RB'), ('sensitive', 'JJ'), ('to', 'TO'), ('touch', 'VB'), ('and', 'CC'), ('taste', 'NN'), ('.', '.'), ('Octopuses', 'NNS'), ('are', 'VBP'), ('known', 'VBN'), ('for', 'IN'), ('their', 'PRP$'), ('exceptional', 'JJ'), ('problem-solving', 'NN'), ('abilities', 'NNS'), (',', ','), ('which', 'WDT'), ('are', 'VBP'), ('attributed', 'VBN'), ('to', 'TO'), ('their', 'PRP$'), ('well-developed', 'JJ'), ('nervous', 'JJ'), ('system', 'NN'), ('and', 'CC'), ('complex', 'JJ'), ('brain', 'NN'), ('.', '.'), ('One', 'CD'), ('of', 'IN'), ('the', 'DT'), ('most', 'RBS'), ('intriguing', 'JJ'), ('features', 'NNS'), ('of', 'IN'), ('octopuses', 'NNS'), ('is', 'VBZ'), ('their', 'PRP$'), ('ability', 'NN'), ('to', 'TO'), ('change', 'VB'), ('color', 'NN'), ('and', 'CC'), ('texture', 'NN'), ('rapidly', 'RB'), (',', ','), ('allowing', 'VBG'), ('them', 'PRP'), ('to', 'TO'), ('blend', 'VB'), ('into', 'IN'), ('their', 'PRP$'), ('surroundings', 'NNS'), ('for', 'IN'), ('camouflage', 'NN'), ('or', 'CC'), ('communicate', 'NN'), ('with', 'IN'), ('other', 'JJ'), ('octopuses', 'NNS'), ('.', '.'), ('This', 'DT'), ('camouflaging', 'VBG'), ('ability', 'NN'), ('is', 'VBZ'), ('achieved', 'VBN'), ('through', 'IN'), ('specialized', 'JJ'), ('pigment', 'NN'), ('cells', 'NNS'), ('called', 'VBN'), ('chromatophores', 'NNS'), ('in', 'IN'), ('their', 'PRP$'), ('skin', 'NN'), ('.', '.'), ('Octopuses', 'NNS'), ('are', 'VBP'), ('also', 'RB'), ('known', 'VBN'), ('for', 'IN'), ('their', 'PRP$'), ('intelligence', 'NN'), (',', ','), ('exhibiting', 'VBG'), ('advanced', 'JJ'), ('problem-solving', 'JJ'), ('skills', 'NNS'), (',', ','), ('memory', 'NN'), (',', ','), ('and', 'CC'), ('the', 'DT'), ('ability', 'NN'), ('to', 'TO'), ('learn', 'VB'), ('through', 'IN'), ('observation', 'NN'), ('.', '.'), ('They', 'PRP'), ('have', 'VBP'), ('been', 'VBN'), ('observed', 'VBN'), ('using', 'VBG'), ('tools', 'NNS'), (',', ','), ('escaping', 'VBG'), ('from', 'IN'), ('predators', 'NNS'), (',', ','), ('and', 'CC'), ('even', 'RB'), ('opening', 'VBG'), ('jars', 'NNS'), ('to', 'TO'), ('access', 'NN'), ('food', 'NN'), ('.', '.'), ('Some', 'DT'), ('species', 'NNS'), ('of', 'IN'), ('octopuses', 'NNS'), ('are', 'VBP'), ('also', 'RB'), ('known', 'VBN'), ('for', 'IN'), ('their', 'PRP$'), ('unique', 'JJ'), ('behaviors', 'NNS'), (',', ','), ('such', 'JJ'), ('as', 'IN'), ('mimicry', 'NN'), (',', ','), ('where', 'WRB'), ('they', 'PRP'), ('imitate', 'VBP'), ('other', 'JJ'), ('marine', 'NN'), ('animals', 'NNS'), ('to', 'TO'), ('avoid', 'VB'), ('predators', 'NNS'), ('.', '.'), ('Reproduction', ' ...
